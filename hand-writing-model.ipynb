# %%
import os
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../input/hand-writing-dataset/ML_Project_DataBase.csv')
df.head()
base_path = '/kaggle/input/hand-writing-dataset/'
img_path = os.path.join(base_path, df['Image'].iloc[0].replace("\\", "/"))
img = Image.open(img_path)
print(img_path)
display(img)
# Out:
# /kaggle/input/hand-writing-dataset/SentencePictures/Sentence_001.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=780x50>
